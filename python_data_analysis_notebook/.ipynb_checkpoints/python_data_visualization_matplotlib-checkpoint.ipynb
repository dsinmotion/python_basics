# %% [markdown]
# # Python Visualization with MatPlotlib
# > The [matplotlib](http://matplotlib.org) library is a powerful tool capable of producing complex publication-quality figures with fine layout control in two and three dimensions;
#
# > The best way to learn Matplotlib is to read the tutorials included with the matplotlib documentation as well as to browse its extensive gallery of examples that include source code.
#
# > Just as we typically use the shorthand `np` for Numpy, we will use `plt` for the `matplotlib.pyplot` module where the easy-to-use plotting functions reside (the library contains a rich object-oriented architecture that we don't have the space to discuss here):
#
# ### Useful links
# > - [matplotlib galleries](http://matplotlib.org/gallery.html)

# %% [markdown]
# ----

# %% [markdown]
# #Outlines
# - ###Matplotlib Basics
# - ###Working with diagrams
#   - dots
#   - line chart
#   - pie chart
#   - scatterplots
#   - histgram
#   - heatmap
# - ###Working with images
#   - image
# - ###Simple 3D plotting
# - ###Working with maps
#   -

# %% [markdown]
# ----

# %% [markdown]
# # 1 - Matplotlib Basics

# %%
# %pylab inline
import matplotlib.pylab as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### simple dots

# %%
### Plotting dots
x = np.arange(0,1,0.03)
y = x**2
plt.plot(x, y, "ro")
# Out:
# [ 0.    0.03  0.06  0.09  0.12  0.15  0.18  0.21  0.24  0.27  0.3   0.33
#   0.36  0.39  0.42  0.45  0.48  0.51  0.54  0.57  0.6   0.63  0.66  0.69
#   0.72  0.75  0.78  0.81  0.84  0.87  0.9   0.93  0.96  0.99]

# %% [markdown]
# #### simple lines

# %%
### Plotting line

x = np.arange(0,1,0.03)
y = x**2
plt.plot(x, y)

# %%
x = np.linspace(0, 2*np.pi, 30)
print x
y = np.sin(x)
plt.plot(x, y)
plt.plot(x, y, 'o', markersize=5, color='r');
# Out:
# [ 0.          0.21666156  0.43332312  0.64998469  0.86664625  1.08330781
#   1.29996937  1.51663094  1.7332925   1.94995406  2.16661562  2.38327719
#   2.59993875  2.81660031  3.03326187  3.24992343  3.466585    3.68324656
#   3.89990812  4.11656968  4.33323125  4.54989281  4.76655437  4.98321593
#   5.1998775   5.41653906  5.63320062  5.84986218  6.06652374  6.28318531]

# %%
x = np.linspace(0, 2*np.pi, 300)
y = np.sin(x)
y2 = np.sin(x**2)
plt.plot(x, y, label=r'$\sin(x)$')
plt.plot(x, y2, label=r'$\sin(x^2)$')
plt.title('Some functions')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()

# %% [markdown]
# ####A simple error bar

# %%
# example data
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

# example variable error bar values
yerr = 0.1 + 0.2*np.sqrt(x)
xerr = 0.1 + yerr

# First illustrate basic pyplot interface, using defaults where possible.
plt.figure()
plt.errorbar(x, y, xerr=0.2, yerr=0.4)
plt.title("Simplest errorbars, 0.2 in x, 0.4 in y");

# %% [markdown]
# ####A simple logplot

# %%
x = np.linspace(-5, 5)
y = np.exp(-x**2)
plt.semilogy(x, y);

# %% [markdown]
# ----

# %% [markdown]
# # 2 - Popular Diagrams

# %% [markdown]
# ## 2.1 - Plotting Dots

# %% [markdown]
# ## 2.2 - Plotting Lines

# %% [markdown]
# ##2.3 - Scatterplots

# %%
"""
Demo of scatter plot on a polar axis.

Size increases radially in this example and color increases with angle (just to
verify the symbols are being scattered correctly).
"""

num_bootcampers = 212
r = 2*rand(num_bootcampers)
theta = 2*pi*rand(num_bootcampers)
area = 200*r**2*rand(num_bootcampers)
ax = subplot(111,polar=True)
c = scatter(theta, r, c=theta, s=area, alpha=0.75)

# %% [markdown]
# ## 2.x - Histograms

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
# This will put a text fragment at the position given:
plt.text(55, .027, r'$\mu=100,\ \sigma=15$', fontsize=14)
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %% [markdown]
# ## 2.x - Heatmap
# > **imshow** vs. **pcolor** vs. **pcolormesh**
# >> [when to use imshow over pcolormesh?](http://stackoverflow.com/questions/21166679/when-to-use-imshow-over-pcolormesh)
#
# >> [difference between imshow, pcolor and pcolormesh](http://thomas-cokelaer.info/blog/2014/05/matplotlib-difference-between-pcolor-pcolormesh-and-imshow/)

# %%
# plotting heatmap using imshow
plt.imshow(rand(5,10), interpolation='nearest', cmap=cm.Blues)

# %% [markdown]
# ----

# %% [markdown]
# # 3 - Plotting Images

# %% [markdown]
# ## 3.1

# %%
img = plt.imread('images/dessert.png')
img.shape
# Out:
# (500, 319, 3)

# %%
plt.imshow(img)

# %% [markdown]
# Plot the r, g, b channels of the image.

# %%
fig, ax = plt.subplots(1,4, figsize=(10,6))
print type(fig)
print type(ax)

ax[0].imshow(img[:,:,0], cmap=cm.Reds_r)
ax[1].imshow(img[:,:,1], cmap=cm.Blues_r)
ax[2].imshow(img[:,:,2], cmap=cm.Greens_r)
ax[3].imshow(img);
for a in ax:
    a.set_xticklabels([])
    a.set_yticklabels([])
# Out:
# <class 'matplotlib.figure.Figure'>
# <type 'numpy.ndarray'>

# %% [markdown]
# ----

# %% [markdown]
# # 4 - Simple 3D Plotting

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# One this has been done, you can create 3d axes with the `projection='3d'` keyword to `add_subplot`:
#
#     fig = plt.figure()
#     fig.add_subplot(<other arguments here>, projection='3d')

# %% [markdown]
# ####A simple surface plot:

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.jet,
        linewidth=0, antialiased=False)
ax.set_zlim3d(-1.01, 1.01);
